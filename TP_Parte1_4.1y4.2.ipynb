# %%
#Dataset
import matplotlib.pyplot as plt
import numpy
import pandas
import seaborn

dataset = pandas.read_csv(
    'https://object.cato.org/sites/cato.org/files/human-freedom-index-files/human-freedom-index-2019.csv')

score_cols = [col for col in dataset.columns if 'pf_identity' in col] + [
    'pf_score', # Personal Freedom (score)
    'pf_rank', # Personal Freedom (rank)
    'ef_score', # Economic Freedom (score)
    'ef_rank', # Economic Freedom (rank)
    'hf_score', # Human Freedom (score)
    'hf_rank', # Human Freedom (rank)
]

important_cols = ['year', 'ISO_code', 'countries', 'region'] + score_cols

dataset[important_cols]

dataset = dataset[important_cols].replace('-', numpy.nan)
for score_col in score_cols:
  dataset[score_col] = pandas.to_numeric(dataset[score_col])

display(dataset.head())
# Out:
#    year ISO_code  countries                         region  pf_identity_legal  \
# 0  2017      ALB    Albania                 Eastern Europe                0.0
# 1  2017      DZA    Algeria     Middle East & North Africa                NaN
# 2  2017      AGO     Angola             Sub-Saharan Africa               10.0
# 3  2017      ARG  Argentina  Latin America & the Caribbean               10.0
# 4  2017      ARM    Armenia        Caucasus & Central Asia                7.0
#
#    pf_identity_sex_male  pf_identity_sex_female  pf_identity_sex  \
# 0                  10.0                    10.0             10.0
# 1                   0.0                     0.0              0.0
# 2                   0.0                     0.0              0.0
# 3                  10.0                    10.0             10.0
# 4                  10.0                    10.0             10.0
#
#    pf_identity_divorce  pf_identity  pf_score  pf_rank  ef_score  ef_rank  \
# 0                  7.5          5.8      8.01     46.0      7.67     30.0
# 1                  0.0          0.0      5.20    146.0      4.77    159.0
# 2                  5.0          5.0      5.98    121.0      4.83    158.0
# 3                 10.0         10.0      8.04     41.0      5.67    147.0
# 4                  7.5          8.2      7.15     72.0      7.70     27.0
#
#    hf_score  hf_rank
# 0      7.84     38.0
# 1      4.99    155.0
# 2      5.40    151.0
# 3      6.86     77.0
# 4      7.42     54.0

# %% [markdown]
# EJERCICIO 4.1
# ¿Qué conclusiones puede sacar de un gráfico pairplot de estas tres variables? ¿Es adecuado para los valores de pf_identity? ¿Por qué?

# %%
#Librerias
import pandas as pd
import seaborn as sns
import matplotlib.style as style 

#Datos
display(dataset.head())

#Estilo del gráfico
sns.set_context("notebook")
style.use("seaborn-bright")

#Grafico
g = sns.pairplot(data=dataset, x_vars=["pf_identity", "pf_score"], y_vars="ef_score")
g.fig.set_size_inches(12,12)

#Titulo y print
plt.subplots_adjust(top=0.9)
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle('Relacion entre variables de libertad personal (eje x) y el score de libertad economica (eje y)', fontsize=15, va="center")
plt.show()
# Out:
#    year ISO_code  countries                         region  pf_identity_legal  \
# 0  2017      ALB    Albania                 Eastern Europe                0.0
# 1  2017      DZA    Algeria     Middle East & North Africa                NaN
# 2  2017      AGO     Angola             Sub-Saharan Africa               10.0
# 3  2017      ARG  Argentina  Latin America & the Caribbean               10.0
# 4  2017      ARM    Armenia        Caucasus & Central Asia                7.0
#
#    pf_identity_sex_male  pf_identity_sex_female  pf_identity_sex  \
# 0                  10.0                    10.0             10.0
# 1                   0.0                     0.0              0.0
# 2                   0.0                     0.0              0.0
# 3                  10.0                    10.0             10.0
# 4                  10.0                    10.0             10.0
#
#    pf_identity_divorce  pf_identity  pf_score  pf_rank  ef_score  ef_rank  \
# 0                  7.5          5.8      8.01     46.0      7.67     30.0
# 1                  0.0          0.0      5.20    146.0      4.77    159.0
# 2                  5.0          5.0      5.98    121.0      4.83    158.0
# 3                 10.0         10.0      8.04     41.0      5.67    147.0
# 4                  7.5          8.2      7.15     72.0      7.70     27.0
#
#    hf_score  hf_rank
# 0      7.84     38.0
# 1      4.99    155.0
# 2      5.40    151.0
# 3      6.86     77.0
# 4      7.42     54.0

# %% [markdown]
# Conclusiones
# Se observa una correlacion lineal y positiva entre el score de libertades economicas y el score de libertades personales. Se concluye que un aumento de las libertades económicas refiere a un aumento en las libertaes personales.
# Se observa, también, una pendiente bastante marcada, lo que indica una correlacion "fuerte"
# No hay correlación entre las libertades personales referidas a la identidad y las libertades economicas.
# Lo anterior nos da la idea de que pueden coexistir un alto grado de libertad económica sin libertad en cuando a identidades personales y viceversa.

# %% [markdown]
# EJERCICIO 4.2
# Graficar la correlación (visual) entre pf_identity y pf_score; y entre pf_identity y ef_score.
# Analizar el resultado, ¿se pueden sacar conclusiones? Tengan en cuenta que como pf_identity es el resultado de un promedio, sólo toma algunos valores. Es, en la práctica, discreta, y eso afecta al tipo de gráfico que podemos usar.

# %%
#Librerias
import pandas as pd
import seaborn as sns
import matplotlib.style as style 


#Estilo del grafico
sns.set_context("notebook")
style.use("seaborn-bright")

#Grafico 1
g = sns.relplot(data=dataset, x="pf_score", y="pf_identity", kind="scatter")
g.fig.set_size_inches(11,11)

#Titulo y print
plt.subplots_adjust(top=0.9)
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle('Relacion entre libertad identitaria (eje y) y el puntaje de libertad personal (eje x)', fontsize=15, va="center")
plt.show()

#Grafico 2
g = sns.relplot(data=dataset, x="ef_score", y="pf_identity", kind="scatter")
g.fig.set_size_inches(11,11)

#Titulo y print
plt.subplots_adjust(top=0.9)
g.fig.subplots_adjust(top=0.9)
g.fig.suptitle('Relacion entre el score de libertad identitaria (eje y) y el score de libertad economica (eje x)', fontsize=15, va="center")
plt.show()

# %% [markdown]
# Conclusiones
# Se observa una correlacion entre el score de libertad personal y las libertades identitarias. Si bien existe una marcada disperción de los datos y se puede observar una correlación lineal y positiva.
# Lo anterior nos indica que las libertades personales estan ligadas a las libertades identitarias.
# Nuevamente, no se observa relación entre las libertades personales (en este caso identitarias) y las libertades económicas -segundo gráfico-.

# %%
cols = ['pf_rank', 'ef_rank', 'hf_rank']
correl = dataset[cols]
correl.corr('kendall')

# %%
correl.corr('kendall')
# Out:
#           pf_rank   ef_rank   hf_rank
# pf_rank  1.000000  0.525190  0.815905
# ef_rank  0.525190  1.000000  0.710294
# hf_rank  0.815905  0.710294  1.000000
